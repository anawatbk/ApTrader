# %% [markdown]
# # AAPL Data Loading Test with S3 Stock Client
#
# This notebook demonstrates how to use the S3StockDataClient to load Apple (AAPL) stock data from our S3 parquet storage.

# %% [markdown]
# ## Setup and Configuration

# %%
import pandas as pd
import logging

from clients import DuckDBStockClient
# Import the S3 client
from clients.s3_stock_client import S3StockDataClient

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

print("Setup complete!")
# Out:
# Setup complete!

# %% [markdown]
# ## Initialize S3 Stock Client
#
# Configure the client to connect to our S3 bucket containing the processed stock data.

# %%
client = DuckDBStockClient()
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %%
client.get_data(tickers='AAPL', years=2025)
# Out:
#           window_start_et      open     high      low     close   volume  \
# 0     2025-03-12 09:30:00  220.1400  220.500  219.270  219.8450  1376617
# 1     2025-03-12 09:31:00  219.7601  220.330  219.560  219.6600   294749
# 2     2025-03-12 09:32:00  219.6000  220.245  219.600  219.9700   325246
# 3     2025-03-12 09:33:00  219.9700  220.500  219.970  220.1650   388737
# 4     2025-03-12 09:34:00  220.1800  221.300  220.130  220.4365   523188
# ...                   ...       ...      ...      ...       ...      ...
# 27295 2025-06-20 15:55:00  200.5600  201.700  200.560  201.3500  1799984
# 27296 2025-06-20 15:56:00  201.3300  201.420  201.025  201.0900   757154
# 27297 2025-06-20 15:57:00  201.0900  201.170  200.860  200.9750   796178
# 27298 2025-06-20 15:58:00  200.9800  201.090  200.930  200.9500   885863
# 27299 2025-06-20 15:59:00  200.9400  201.090  200.680  200.9200  2326359
#
#        transactions ticker  year
# 0             15261   AAPL  2025
# 1              4466   AAPL  2025
# 2              4759   AAPL  2025
# 3              4894   AAPL  2025
# 4              5792   AAPL  2025
# ...             ...    ...   ...
# 27295         16704   AAPL  2025
# 27296          7816   AAPL  2025
# 27297          8860   AAPL  2025
# 27298          8519   AAPL  2025
# 27299         20317   AAPL  2025
#
# [27300 rows x 9 columns]

# %%
# Initialize the S3 client
client_s3 = S3StockDataClient(
    bucket="anawatp-us-stocks",
    base_prefix="parquet", 
    aws_region="us-west-2",  # Match the region from our ETL job
    cache_enabled=False  # Disable caching for testing
)
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %% [markdown]
# ## Explore Available Data
#
# Let's see what years and tickers are available in our dataset.

# %%
client_s3.get_available_tickers()
# Out:
# ['A',
#  'AA',
#  'AAA',
#  'AAAU',
#  'AACB',
#  'AACBR',
#  'AACBU',
#  'AACG',
#  'AACIU',
#  'AACT',
#  'AACT.U',
#  'AACT.WS',
#  'AADI',
#  'AADR',
#  'AAL',
#  'AAM',
#  'AAM.U',
#  'AAM.WS',
#  'AAME',
#  'AAMI',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPB',
#  'AAPD',
#  'AAPG',
#  'AAPL',
#  'AAPR',
#  'AAPU',
#  'AAPW',
#  'AAPX',
#  'AAPY',
#  'AARD',
#  'AAT',
#  'AAUC',
#  'AAVM',
#  'AAXJ',
#  'AB',
#  'ABAT',
#  'ABBV',
#  'ABCB',
#  'ABCL',
#  'ABCS',
#  'ABEO',
#  'ABEQ',
#  'ABEV',
#  'ABFL',
#  'ABG',
#  'ABHY',
#  'ABIG',
#  'ABL',
#  'ABLD',
#  'ABLG',
#  'ABLLL',
#  'ABLLW',
#  'ABLS',
#  'ABLV',
#  'ABLVW',
#  'ABM',
#  'ABNB',
#  'ABNY',
#  'ABOS',
#  'ABOT',
#  'ABP',
#  'ABPWW',
#  'ABR',
#  'ABRpD',
#  'ABRpE',
#  'ABRpF',
#  'ABSI',
#  'ABT',
#  'ABTS',
#  'ABUS',
#  'ABVC',
#  'ABVE',
#  'ABVEW',
#  'ABVX',
#  'ABXB',
#  'AC',
#  'ACA',
#  'ACAD',
#  'ACB',
#  'ACCD',
#  'ACCO',
#  'ACCS',
#  'ACDC',
#  'ACEL',
#  'ACES',
#  'ACET',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACGR',
#  'ACHC',
#  'ACHL',
#  'ACHR',
#  'ACHR.WS',
#  'ACHV',
#  'ACI',
#  'ACIC',
#  'ACIO',
#  'ACIU',
#  'ACIW',
#  'ACLC',
#  'ACLO',
#  'ACLS',
#  'ACLX',
#  'ACM',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACNT',
#  'ACOG',
#  'ACON',
#  'ACONW',
#  'ACP',
#  'ACPpA',
#  'ACR',
#  'ACRE',
#  'ACRS',
#  'ACRV',
#  'ACRpC',
#  'ACRpD',
#  'ACSI',
#  'ACT',
#  'ACTG',
#  'ACTU',
#  'ACTV',
#  'ACU',
#  'ACV',
#  'ACVA',
#  'ACVF',
#  'ACVT',
#  'ACWI',
#  'ACWV',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADAP',
#  'ADBE',
#  'ADBG',
#  'ADC',
#  'ADCT',
#  'ADCpA',
#  'ADD',
#  'ADEA',
#  'ADFI',
#  'ADGM',
#  'ADI',
#  'ADIL',
#  'ADIV',
#  'ADM',
#  'ADMA',
#  'ADME',
#  'ADN',
#  'ADNT',
#  'ADNWW',
#  'ADP',
#  'ADPT',
#  'ADPV',
#  'ADSE',
#  'ADSEW',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'ADTX',
#  'ADUR',
#  'ADUS',
#  'ADV',
#  'ADVB',
#  'ADVE',
#  'ADVM',
#  'ADVWW',
#  'ADX',
#  'ADXN',
#  'AEE',
#  'AEF',
#  'AEFC',
#  'AEG',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEM',
#  'AEMD',
#  'AENT',
#  'AENTW',
#  'AEO',
#  'AEON',
#  'AEP',
#  'AER',
#  'AERT',
#  'AERTW',
#  'AES',
#  'AESI',
#  'AESR',
#  'AETH',
#  'AEVA',
#  'AEVAW',
#  'AEYE',
#  'AFB',
#  'AFBI',
#  'AFCG',
#  'AFG',
#  'AFGB',
#  'AFGC',
#  'AFGD',
#  'AFGE',
#  'AFIF',
#  'AFIX',
#  'AFJK',
#  'AFJKR',
#  'AFJKU',
#  'AFK',
#  'AFL',
#  'AFLG',
#  'AFMC',
#  'AFMD',
#  'AFRI',
#  'AFRIW',
#  'AFRM',
#  'AFSC',
#  'AFSM',
#  'AFYA',
#  'AG',
#  'AGAE',
#  'AGCO',
#  'AGD',
#  'AGEM',
#  'AGEN',
#  'AGFY',
#  'AGG',
#  'AGGA',
#  'AGGH',
#  'AGGS',
#  'AGGY',
#  'AGH',
#  'AGI',
#  'AGIH',
#  'AGIO',
#  'AGIX',
#  'AGL',
#  'AGM',
#  'AGM.A',
#  'AGMH',
#  'AGMI',
#  'AGMpD',
#  'AGMpE',
#  'AGMpF',
#  'AGMpG',
#  'AGNC',
#  'AGNCL',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGNG',
#  'AGO',
#  'AGOX',
#  'AGQ',
#  'AGQI',
#  'AGRH',
#  'AGRI',
#  'AGRO',
#  'AGRW',
#  'AGS',
#  'AGX',
#  'AGYS',
#  'AGZ',
#  'AGZD',
#  'AHCO',
#  'AHG',
#  'AHH',
#  'AHHpA',
#  'AHL',
#  'AHLT',
#  'AHLpD',
#  'AHLpE',
#  'AHLpF',
#  'AHR',
#  'AHT',
#  'AHTpD',
#  'AHTpF',
#  'AHTpG',
#  'AHTpH',
#  'AHTpI',
#  'AHYB',
#  'AI',
#  'AIA',
#  'AIBD',
#  'AIBU',
#  'AIEQ',
#  'AIEV',
#  'AIFD',
#  'AIFE',
#  'AIFER',
#  'AIFEU',
#  'AIFF',
#  'AIFU',
#  'AIG',
#  'AIHS',
#  'AII',
#  'AIM',
#  'AIMAU',
#  'AIMAW',
#  'AIMBU',
#  'AIMD',
#  'AIMDW',
#  'AIN',
#  'AINP',
#  'AIO',
#  'AIOT',
#  'AIP',
#  'AIPI',
#  'AIQ',
#  'AIR',
#  'AIRE',
#  'AIRG',
#  'AIRI',
#  'AIRJ',
#  'AIRJW',
#  'AIRL',
#  'AIRO',
#  'AIRR',
#  'AIRS',
#  'AIRT',
#  'AIRTP',
#  'AIS',
#  'AISP',
#  'AISPW',
#  'AIT',
#  'AITR',
#  'AITRR',
#  'AITRU',
#  'AIV',
#  'AIVC',
#  'AIVI',
#  'AIVL',
#  'AIXI',
#  'AIYY',
#  'AIZ',
#  'AIZN',
#  'AJAN',
#  'AJG',
#  'AJUL',
#  'AKA',
#  'AKAM',
#  'AKAN',
#  'AKBA',
#  'AKO.A',
#  'AKO.B',
#  'AKR',
#  'AKRO',
#  'AKTX',
#  'AKYA',
#  'AL',
#  'ALAB',
#  'ALAI',
#  'ALAR',
#  'ALB',
#  'ALBT',
#  'ALBpA',
#  'ALC',
#  'ALCO',
#  'ALCY',
#  'ALCYU',
#  'ALCYW',
#  'ALDF',
#  'ALDFU',
#  'ALDFW',
#  'ALDX',
#  'ALE',
#  'ALEC',
#  'ALEX',
#  'ALF',
#  'ALFUU',
#  'ALFUW',
#  'ALG',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIL',
#  'ALIT',
#  'ALK',
#  'ALKS',
#  'ALKT',
#  'ALL',
#  'ALLE',
#  'ALLK',
#  'ALLO',
#  'ALLR',
#  'ALLT',
#  'ALLW',
#  'ALLY',
#  'ALLpB',
#  'ALLpH',
#  'ALLpI',
#  'ALLpJ',
#  'ALMS',
#  'ALMU',
#  'ALNT',
#  'ALNY',
#  'ALOT',
#  'ALRM',
#  'ALRS',
#  'ALSN',
#  'ALT',
#  'ALTG',
#  'ALTGpA',
#  'ALTI',
#  'ALTL',
#  'ALTO',
#  'ALTR',
#  'ALTS',
#  'ALTY',
#  'ALUR',
#  'ALUR.WS',
#  'ALV',
#  'ALVO',
#  'ALVOW',
#  'ALVR',
#  'ALX',
#  'ALXO',
#  'ALZN',
#  'AM',
#  'AMAL',
#  'AMAT',
#  'AMAX',
#  'AMBA',
#  'AMBC',
#  'AMBI',
#  'AMBI.WS',
#  'AMBO',
#  'AMBP',
#  'AMBP.WS',
#  'AMBR',
#  'AMC',
#  'AMCR',
#  'AMCX',
#  'AMD',
#  'AMDD',
#  'AMDG',
#  'AMDL',
#  'AMDS',
#  'AMDY',
#  'AME',
#  'AMED',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMHpG',
#  'AMHpH',
#  'AMID',
#  'AMIX',
#  'AMJB',
#  'AMKR',
#  'AMLP',
#  'AMLX',
#  'AMN',
#  'AMOD',
#  'AMODW',
#  'AMOM',
#  'AMP',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPL',
#  'AMPS',
#  'AMPX',
#  'AMPX.WS',
#  'AMPY',
#  'AMR',
#  'AMRC',
#  'AMRK',
#  'AMRN',
#  'AMRX',
#  'AMS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMT',
#  'AMTB',
#  'AMTD',
#  'AMTM',
#  'AMTX',
#  'AMUB',
#  'AMUU',
#  'AMWD',
#  'AMWL',
#  'AMX',
#  'AMZA',
#  'AMZD',
#  'AMZE',
#  'AMZN',
#  'AMZP',
#  'AMZU',
#  'AMZW',
#  'AMZY',
#  'AMZZ',
#  'AN',
#  'ANAB',
#  'ANDE',
#  'ANEB',
#  'ANET',
#  'ANEW',
#  'ANF',
#  'ANGH',
#  'ANGHW',
#  'ANGI',
#  'ANGIV',
#  'ANGL',
#  'ANGO',
#  'ANGpB',
#  'ANGpD',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANL',
#  'ANNA',
#  'ANNAW',
#  'ANNX',
#  'ANRO',
#  'ANSC',
#  'ANSCU',
#  'ANSCW',
#  'ANSS',
#  'ANTA',
#  'ANTE',
#  'ANTX',
#  'ANVS',
#  'ANY',
#  'AOA',
#  'AOCT',
#  'AOD',
#  'AOHY',
#  'AOK',
#  'AOM',
#  'AOMD',
#  'AOMN',
#  'AOMR',
#  'AON',
#  'AOR',
#  'AORT',
#  'AOS',
#  'AOSL',
#  'AOTG',
#  'AOUT',
#  'AP',
#  'AP.WS',
#  'APA',
#  'APAM',
#  'APCB',
#  'APCX',
#  'APCXW',
#  'APD',
#  'APDN',
#  'APED',
#  'APEI',
#  'APG',
#  'APGE',
#  'APH',
#  'API',
#  'APIE',
#  'APLD',
#  'APLE',
#  'APLM',
#  'APLMW',
#  'APLS',
#  'APLT',
#  'APLU',
#  'APLY',
#  'APM',
#  'APMU',
#  'APO',
#  'APOC',
#  'APOG',
#  'APOS',
#  'APOpA',
#  'APP',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APPX',
#  'APRD',
#  'APRE',
#  'APRH',
#  'APRJ',
#  'APRP',
#  'APRQ',
#  'APRT',
#  'APRW',
#  'APRZ',
#  'APT',
#  'APTO',
#  'APTV',
#  'APUE',
#  'APUS',
#  'APVO',
#  'APWC',
#  'APXM',
#  'APYX',
#  'AQB',
#  'AQLT',
#  'AQMS',
#  'AQN',
#  'AQNB',
#  'AQST',
#  'AQWA',
#  'AR',
#  'ARAI',
#  'ARAY',
#  'ARB',
#  'ARBB',
#  'ARBE',
#  'ARBEW',
#  'ARBK',
#  'ARBKL',
#  'ARCB',
#  'ARCC',
#  'ARCM',
#  'ARCO',
#  'ARCT',
#  'ARCX',
#  'ARDC',
#  'ARDT',
#  'ARDX',
#  'ARE',
#  'AREA',
#  'AREB',
#  'AREBW',
#  'AREC',
#  'AREN',
#  'ARES',
#  'ARESpB',
#  'ARGD',
#  'ARGOpA',
#  'ARGT',
#  'ARGX',
#  'ARHS',
#  'ARI',
#  'ARIS',
#  'ARKA',
#  'ARKB',
#  'ARKC',
#  'ARKD',
#  'ARKF',
#  'ARKG',
#  'ARKK',
#  'ARKO',
#  'ARKOW',
#  'ARKQ',
#  'ARKR',
#  'ARKW',
#  'ARKX',
#  'ARKY',
#  'ARKZ',
#  'ARL',
#  'ARLO',
#  'ARLP',
#  'ARLU',
#  'ARM',
#  'ARMG',
#  'ARMH',
#  'ARMK',
#  'ARMN',
#  'ARMP',
#  'ARMU',
#  'AROC',
#  'AROW',
#  'ARP',
#  'ARQ',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARR',
#  'ARRY',
#  'ARRpC',
#  'ARTL',
#  'ARTNA',
#  'ARTV',
#  'ARTW',
#  'ARTY',
#  'ARVN',
#  'ARVR',
#  'ARW',
#  'ARWR',
#  'AS',
#  'ASA',
#  'ASAN',
#  'ASB',
#  'ASBA',
#  'ASBP',
#  'ASBPW',
#  'ASBpE',
#  'ASBpF',
#  'ASC',
#  'ASEA',
#  'ASET',
#  'ASG',
#  'ASGI',
#  'ASGN',
#  'ASH',
#  'ASHR',
#  'ASHS',
#  'ASIA',
#  'ASIC',
#  'ASIX',
#  'ASLE',
#  'ASLV',
#  'ASM',
#  'ASMB',
#  'ASMF',
#  'ASMG',
#  'ASMH',
#  'ASML',
#  'ASND',
#  'ASNS',
#  'ASO',
#  'ASPC',
#  'ASPCR',
#  'ASPCU',
#  'ASPI',
#  'ASPN',
#  'ASPS',
#  'ASPSW',
#  'ASPSZ',
#  'ASR',
#  'ASRT',
#  'ASRV',
#  'ASST',
#  'ASTC',
#  'ASTE',
#  'ASTH',
#  'ASTI',
#  'ASTL',
#  'ASTLW',
#  'ASTS',
#  'ASUR',
#  'ASX',
#  'ASYS',
#  'ATAI',
#  'ATAT',
#  'ATCH',
#  'ATCOL',
#  'ATCOpD',
#  'ATCOpH',
#  'ATEC',
#  'ATEN',
#  'ATER',
#  'ATEX',
#  'ATFV',
#  'ATGE',
#  'ATGL',
#  'ATHA',
#  'ATHE',
#  'ATHM',
#  'ATHR',
#  'ATHS',
#  'ATHpA',
#  'ATHpB',
#  'ATHpC',
#  'ATHpD',
#  'ATHpE',
#  'ATI',
#  'ATII',
#  'ATIIU',
#  'ATIIW',
#  'ATKR',
#  'ATLC',
#  'ATLCL',
#  'ATLCP',
#  'ATLCZ',
#  'ATLN',
#  'ATLO',
#  'ATLX',
#  'ATMC',
#  'ATMCR',
#  'ATMCU',
#  'ATMCW',
#  'ATMP',
#  'ATMU',
#  'ATMV',
#  'ATMVR',
#  'ATMVU',
#  'ATNF',
#  'ATNFW',
#  'ATNI',
#  'ATNM',
#  'ATO',
#  'ATOM',
#  'ATOS',
#  'ATPC',
#  'ATR',
#  'ATRA',
#  'ATRC',
#  'ATRO',
#  'ATS',
#  'ATSG',
#  'ATUS',
#  'ATXG',
#  'ATXI',
#  'ATXS',
#  'ATYR',
#  'AU',
#  'AUB',
#  'AUBN',
#  'AUBpA',
#  'AUDC',
#  'AUGM',
#  'AUGP',
#  'AUGT',
#  'AUGU',
#  'AUGW',
#  'AUGZ',
#  'AUID',
#  'AUMI',
#  'AUNA',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AUROW',
#  'AUSF',
#  'AUST',
#  'AUTL',
#  'AUUD',
#  'AUUDW',
#  'AVA',
#  'AVAH',
#  'AVAL',
#  'AVAV',
#  'AVB',
#  'AVBP',
#  'AVD',
#  'AVDE',
#  'AVDL',
#  'AVDS',
#  'AVDV',
#  'AVDX',
#  'AVEE',
#  'AVEM',
#  'AVES',
#  'AVGB',
#  'AVGE',
#  'AVGG',
#  'AVGO',
#  'AVGV',
#  'AVGX',
#  'AVIE',
#  'AVIG',
#  'AVIR',
#  'AVIV',
#  'AVK',
#  'AVL',
#  'AVLC',
#  'AVLV',
#  'AVMA',
#  'AVMC',
#  'AVMU',
#  'AVMV',
#  'AVNM',
#  'AVNS',
#  'AVNT',
#  'AVNV',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVPTW',
#  'AVR',
#  'AVRE',
#  'AVS',
#  'AVSC',
#  'AVSD',
#  'AVSE',
#  'AVSF',
#  'AVSU',
#  'AVT',
#  'AVTE',
#  'AVTR',
#  'AVTX',
#  'AVUQ',
#  'AVUS',
#  'AVUV',
#  'AVXC',
#  'AVXL',
#  'AVY',
#  'AWAY',
#  'AWEG',
#  'AWF',
#  'AWH',
#  'AWI',
#  'AWK',
#  'AWP',
#  'AWR',
#  'AWRE',
#  'AWX',
#  'AX',
#  'AXDX',
#  'AXGN',
#  'AXIL',
#  'AXINU',
#  'AXL',
#  'AXON',
#  'AXP',
#  'AXR',
#  'AXS',
#  'AXSM',
#  'AXSpE',
#  'AXTA',
#  'AXTI',
#  'AYI',
#  'AYRO',
#  'AYTU',
#  'AZ',
#  'AZEK',
#  'AZI',
#  'AZN',
#  'AZNH',
#  'AZO',
#  'AZTA',
#  'AZTD',
#  'AZTR',
#  'AZUL',
#  'AZZ',
#  'B',
#  'BA',
#  'BAB',
#  'BABA',
#  'BABO',
#  'BABX',
#  'BAC',
#  'BACCU',
#  'BACK',
#  'BACQ',
#  'BACQR',
#  'BACQU',
#  'BACpB',
#  'BACpE',
#  'BACpK',
#  'BACpL',
#  'BACpM',
#  'BACpN',
#  'BACpO',
#  'BACpP',
#  'BACpQ',
#  'BACpS',
#  'BAER',
#  'BAERW',
#  'BAFE',
#  'BAFN',
#  'BAGY',
#  'BAH',
#  'BAI',
#  'BAK',
#  'BALI',
#  'BALL',
#  'BALT',
#  'BALY',
#  'BAM',
#  'BAMA',
#  'BAMB',
#  'BAMD',
#  'BAMG',
#  'BAMO',
#  'BAMU',
#  'BAMV',
#  'BAMY',
#  'BANC',
#  'BANCpF',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANL',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BAP',
#  'BAPR',
#  'BAR',
#  'BARK',
#  'BARK.WS',
#  'BASE',
#  'BASG',
#  'BASV',
#  'BATL',
#  'BATRA',
#  'BATRK',
#  'BATT',
#  'BAUG',
#  'BAX',
#  'BAYA',
#  'BAYAR',
#  'BAYAU',
#  'BApA',
#  'BB',
#  'BBAG',
#  'BBAI',
#  'BBAI.WS',
#  'BBAR',
#  ...]

# %% [markdown]
# ## Examine Data Structure
#
# Let's look at the first few rows and basic statistics.

# %%
result = client_s3.get_data(tickers='AAPL', years=2025)
result
# Out:
#           window_start_et     open    high       low   close   volume  \
# 0     2025-05-28 09:30:00  200.590  201.53  200.5000  201.34   931287
# 1     2025-04-07 09:30:00  177.200  177.97  176.1000  177.31  7591929
# 2     2025-05-28 09:31:00  201.270  201.77  201.2500  201.68   259238
# 3     2025-04-07 09:31:00  177.355  177.98  175.6200  177.60  1637954
# 4     2025-05-28 09:32:00  201.681  202.69  201.6810  202.61   425147
# ...                   ...      ...     ...       ...     ...      ...
# 27295 2025-04-15 15:55:00  202.590  202.77  202.4300  202.48   234190
# 27296 2025-04-15 15:56:00  202.470  202.54  202.3601  202.51   167573
# 27297 2025-04-15 15:57:00  202.515  202.53  202.2500  202.28   200028
# 27298 2025-04-15 15:58:00  202.285  202.33  202.1300  202.14   291442
# 27299 2025-04-15 15:59:00  202.140  202.27  201.9200  202.13  1100507
#
#        transactions  year ticker
# 0             12470  2025   AAPL
# 1             53401  2025   AAPL
# 2              3549  2025   AAPL
# 3             20621  2025   AAPL
# 4              5212  2025   AAPL
# ...             ...   ...    ...
# 27295          3605  2025   AAPL
# 27296          2532  2025   AAPL
# 27297          2820  2025   AAPL
# 27298          3747  2025   AAPL
# 27299         10972  2025   AAPL
#
# [27300 rows x 9 columns]

# %% [markdown]
# ## Test Date Range Filtering
#
# Let's test loading AAPL data for a specific date range.

# %%
client.get_data(tickers='AAPL', start_date='2025-03-12', end_date='2025-03-15')
# Out:
#           window_start_et     open    high     low     close   volume  \
# 5460  2025-03-13 09:30:00  215.950  216.03  214.90  215.1732  1481429
# 5462  2025-03-13 09:31:00  215.150  215.65  215.02  215.1300   244927
# 5464  2025-03-13 09:32:00  215.170  215.66  214.69  214.7600   265537
# 5466  2025-03-13 09:33:00  214.790  215.10  214.37  214.6050   407137
# 5468  2025-03-13 09:34:00  214.615  214.96  214.37  214.8800   313900
# ...                   ...      ...     ...     ...       ...      ...
# 24565 2025-03-12 15:55:00  216.800  217.27  216.80  217.1200   545098
# 24566 2025-03-12 15:56:00  217.100  217.19  216.91  217.1000   411316
# 24567 2025-03-12 15:57:00  217.100  217.17  216.97  217.1700   391577
# 24568 2025-03-12 15:58:00  217.165  217.27  217.07  217.2000   479251
# 24569 2025-03-12 15:59:00  217.205  217.28  216.88  216.9400  1238500
#
#        transactions  year ticker
# 5460          15341  2025   AAPL
# 5462           3009  2025   AAPL
# 5464           4485  2025   AAPL
# 5466           5654  2025   AAPL
# 5468           4605  2025   AAPL
# ...             ...   ...    ...
# 24565          7065  2025   AAPL
# 24566          4686  2025   AAPL
# 24567          5161  2025   AAPL
# 24568          5999  2025   AAPL
# 24569         13053  2025   AAPL
#
# [1170 rows x 9 columns]
